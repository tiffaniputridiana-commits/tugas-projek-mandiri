# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([[1],
              [0],
              [0]])
x
# Out:
# array([[1],
#        [0],
#        [0]])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
# tampilkan ukuran vector x
x.shape
# Out:
# (3, 1)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0] # zero-indexed
# Out:
# array([1])

# %%
# tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.ndarray

# %% [markdown]
# Soal 2

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([[1, 0, 0]])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (1, 3)

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[1],
              [0],
              [0]])
y_t = y.T
y_t
# Out:
# array([[1, 0, 0]])

# %%
# tampilkan ukuran dari vector y_t
y_t.shape
# Out:
# (1, 3)

# %% [markdown]
# Soal 3 lakukan soal nomor 2 menggunakan pytorch dan tensorflow

# %%
import torch as pt

# %%
x = pt.tensor([[1],
               [0],
               [0]])
x
# Out:
# tensor([[1],
#         [0],
#         [0]])

# %%
x_t = x.T
x_t
# Out:
# tensor([[1, 0, 0]])

# %%
x_t.shape
# Out:
# torch.Size([1, 3])

# %%
y = pt.tensor([[1],
               [0],
               [0]])
y
# Out:
# tensor([[1],
#         [0],
#         [0]])

# %%
y_t = y.T
y_t
# Out:
# tensor([[1, 0, 0]])

# %%
import tensorflow as tf

# %%
x = tf.constant([[1],
                 [0],
                 [0]])
x
# Out:
# <tf.Tensor: shape=(3, 1), dtype=int32, numpy=
# array([[1],
#        [0],
#        [0]], dtype=int32)>

# %%
x_t = tf.transpose(x)
x_t
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[1, 0, 0]], dtype=int32)>

# %%
y = tf.constant([[1],
                 [0],
                 [0]])
y
# Out:
# <tf.Tensor: shape=(3, 1), dtype=int32, numpy=
# array([[1],
#        [0],
#        [0]], dtype=int32)>

# %%
y_t = tf.transpose(y)
y_t
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[1, 0, 0]], dtype=int32)>
