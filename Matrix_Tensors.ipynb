# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[5, 3, 2], [1, 0, 0]])
X
# Out:
# array([[5, 3, 2],
#        [1, 0, 0]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([5, 1])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([1, 0, 0])

# %% [markdown]
# Soal 2

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[5, 3, 2], [1, 0, 0]])
X_pt
# Out:
# tensor([[5, 3, 2],
#         [1, 0, 0]])

# %%
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
X_pt[:,0]
# Out:
# tensor([5, 1])

# %%
X_pt[1,:]
# Out:
# tensor([1, 0, 0])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[5, 3, 2], [1, 0, 0]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[5, 3, 2],
#        [1, 0, 0]], dtype=int32)>

# %%
X_tf.shape
# Out:
# TensorShape([2, 3])

# %%
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([5, 1], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 0, 0], dtype=int32)>
